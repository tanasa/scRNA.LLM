# %%
# === Standard Library ===
import os
import gc
import datetime
import warnings
from collections import Counter

# === Data & Math ===
import numpy as np
import pandas as pd
import torch

# === Hugging Face & Transformers ===
import transformers
from huggingface_hub import snapshot_download
from datasets import load_from_disk, Dataset

# === Geneformer ===
from geneformer import EmbExtractor, Classifier
import pickle

# Suppress warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# ==============================
# Environment setup
# ==============================
import os
import sys
import torch
import gc
import warnings 

env_path = "/home/btanasa/miniconda3/envs/torch-cu"
os.environ["CONDA_PREFIX"] = env_path
os.environ["CONDA_DEFAULT_ENV"] = "torch-cu"
os.environ["RETICULATE_PYTHON"] = f"{env_path}/bin/python"
print("✅ Environment set to torch-cu")
print("Python executable:", sys.executable)


print("✅ Environment set to torch_cu")
print("Python executable:", sys.executable)
print("CONDA_PREFIX:", os.environ.get("CONDA_PREFIX"))
print("CONDA_DEFAULT_ENV:", os.environ.get("CONDA_DEFAULT_ENV"))

# Verify the setup
try:
    import torch
    print("✅ PyTorch available:", torch.__version__)
    print("✅ CUDA available:", torch.cuda.is_available())
except ImportError as e:
    print("❌ PyTorch import failed:", e)

try:
    from geneformer import TranscriptomeTokenizer
    print("✅ Geneformer available")
except ImportError as e:
    print("❌ Geneformer import failed:", e)

# Suppress warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Clear GPU cache
torch.cuda.empty_cache()
gc.collect()

# Check GPU memory
print(f"GPU memory allocated: {torch.cuda.memory_allocated() / 1024**3:.2f} GB")
print(f"GPU memory reserved: {torch.cuda.memory_reserved() / 1024**3:.2f} GB")

torch.cuda.empty_cache()
print(f"CUDA memory after empty_cache: {torch.cuda.memory_allocated() / (1024**3):.2f} GB")

print("✅ Environment variable set!")
print(f"PYTORCH_CUDA_ALLOC_CONF: {os.environ.get('PYTORCH_CUDA_ALLOC_CONF')}")
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

print("✅ Environment variable set!")
print(f"PYTORCH_CUDA_ALLOC_CONF: {os.environ.get('PYTORCH_CUDA_ALLOC_CONF')}")
# Out:
# ✅ Environment set to torch-cu
# Python executable: /home/btanasa/miniconda3/envs/torch-cu/bin/python
# ✅ Environment set to torch_cu
# Python executable: /home/btanasa/miniconda3/envs/torch-cu/bin/python
# CONDA_PREFIX: /home/btanasa/miniconda3/envs/torch-cu
# CONDA_DEFAULT_ENV: torch-cu
# ✅ PyTorch available: 2.5.1
# ✅ CUDA available: True
# ✅ Geneformer available
# GPU memory allocated: 0.00 GB
# GPU memory reserved: 0.00 GB
# CUDA memory after empty_cache: 0.00 GB
# ✅ Environment variable set!
# PYTORCH_CUDA_ALLOC_CONF: None
# ✅ Environment variable set!
# PYTORCH_CUDA_ALLOC_CONF: expandable_segments:True

# %%
# the model was saved in the location :
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_out/250821141257/

# model_version1="V1"
model_version2="V2"

token_dictionary_file = "/mnt/nfs/CX000008_DS1/projects/btanasa/Geneformer/geneformer/token_dictionary_gc104M.pkl"  # or your V1 or V2 token dict
token_dict_path = token_dictionary_file

with open(token_dictionary_file, "rb") as f:
    token_dict = pickle.load(f)

print(type(token_dict))
print(len(token_dict))

# Show first 20 entries
for i, (gene, token_id) in enumerate(token_dict.items()):
    print(f"{gene} → {token_id}")
    if i >= 6:
        break

# Convert to DataFrame
token_df = pd.DataFrame(list(token_dict.items()), columns=["Ensembl_ID", "Token_ID"])
print(token_df)
# Out:
# <class 'dict'>
# 20275
# <pad> → 0
# <mask> → 1
# <cls> → 2
# <eos> → 3
# ENSG00000000003 → 4
# ENSG00000000005 → 5
# ENSG00000000419 → 6
#             Ensembl_ID  Token_ID
# 0                <pad>         0
# 1               <mask>         1
# 2                <cls>         2
# 3                <eos>         3
# 4      ENSG00000000003         4
# ...                ...       ...
# 20270  ENSG00000292379     20270
# 20271  ENSG00000292438     20271
# 20272  ENSG00000293543     20272
# 20273  ENSG00000293552     20273
# 20274  ENSG00000293553     20274
#
# [20275 rows x 2 columns]

# %%
# =============================================================================
# FOLDERS and INFORMATION
# =============================================================================

model_directory = "/mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_out/250821141257/250821_geneformer_cellClassifier_hypoxia_condition_classifier_optimized/ksplit1/checkpoint-1400/"      # pretrained or fine-tuned model folder
input_data_file = "/mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.dataset"

# Verify the paths

if os.path.exists(token_dictionary_file):
    print(f"✅ File exists: {token_dictionary_file}")
else:
    print(f"❌ File does NOT exist: {token_dictionary_file}")

if os.path.exists(model_directory):
    print(f"✅ File exists: {model_directory}")
else:
    print(f"❌ File does NOT exist: {model_directory}")

if os.path.exists(input_data_file):
    print(f"✅ File exists: {input_data_file}")
else:
    print(f"❌ File does NOT exist: {input_data_file}")

# Load the dataset
print(f"\n�� Loading dataset...")
try:
    dataset = load_from_disk(input_data_file)
    print(f"✅ Dataset loaded successfully!")
except Exception as e:
    print(f"❌ Failed to load dataset: {e}")
    exit()
# Out:
# ✅ File exists: /mnt/nfs/CX000008_DS1/projects/btanasa/Geneformer/geneformer/token_dictionary_gc104M.pkl
# ✅ File exists: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_out/250821141257/250821_geneformer_cellClassifier_hypoxia_condition_classifier_optimized/ksplit1/checkpoint-1400/
# ✅ File exists: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.dataset
#
# �� Loading dataset...
# ✅ Dataset loaded successfully!

# %%
# =============================================================================
# BASIC INFORMATION
# =============================================================================

print(f"\n📊 BASIC DATASET INFORMATION:")
print(f"   Total cells: {len(dataset):,}")
print(f"   Dataset type: {type(dataset)}")
print(f"   Number of columns: {len(dataset.column_names)}")

print(f"\n📋 METADATA :")
print(f"   Available metadata : {dataset.column_names}")

print(f"\n�� FEATURE SCHEMA:")
for col_name in dataset.column_names:
    col_type = dataset.features[col_name]
    print(f"   {col_name}: {col_type}")


# Check number of rows and columns
print(dataset.num_rows)
print(dataset.column_names)

# View a sample row
# print(dataset[0])
# print(dataset[1])
# print(dataset[2])

# Data composition :

import pandas as pd

# Convert to DataFrame (if small enough)
df = dataset.to_pandas()

# Unique medical conditions
print("🧍 Unique medical conditions:", df['condition'].nunique())
print(df['condition'].value_counts(), end="\n\n")

# Unique cell types
print("🔬 Unique cell types:", df['class'].nunique())
print(df['class'].value_counts(), end="\n\n")

# Broad cell types
print("🩺 Broad classes of cell populations:", df['broad_class'].nunique())
print(df['broad_class'].value_counts(), end="\n\n")
# Out:
# 📊 BASIC DATASET INFORMATION:
#    Total cells: 2,000
#    Dataset type: <class 'datasets.arrow_dataset.Dataset'>
#    Number of columns: 8
#
# 📋 METADATA :
#    Available metadata : ['input_ids', 'obs_names', 'leiden', 'class', 'condition', 'broad_class', 'length', 'why']
#
# �� FEATURE SCHEMA:
#    input_ids: List(Value('int32'))
#    obs_names: Value('string')
#    leiden: Value('string')
#    class: Value('string')
#    condition: Value('string')
#    broad_class: Value('string')
#    length: Value('int64')
#    why: Value('string')
# 2000
# ['input_ids', 'obs_names', 'leiden', 'class', 'condition', 'broad_class', 'length', 'why']
# 🧍 Unique medical conditions: 3
# condition
# 5d_HIE     1170
# non-HIE     475
# 2mo_HIE     355
# Name: count, dtype: int64
#
# 🔬 Unique cell types: 8
# class
# Astroglia                615
# Imm-MGE                  272
# Inh-Injured              241
# Medium-Spiny-Neuron_?    207
# activated-NSCs           178
# Imm-CGE                  165
# Myelinating-Olig         164
# OPC                      158
# Name: count, dtype: int64
#
# 🩺 Broad classes of cell populations: 2
# broad_class
# Non-Neuronal    1563
# Inhibitory       437
# Name: count, dtype: int64

# %%
# =============================================================================
# CONFIGURATION
# =============================================================================

CONFIG = {

    # Dataset paths
    "input_data_file": "/mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.dataset",

    # Model paths
    "model_path": "/mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_out/250821141257/250821_geneformer_cellClassifier_hypoxia_condition_classifier_optimized/ksplit1/checkpoint-1400/",
    "token_dictionary_file": "/mnt/nfs/CX000008_DS1/projects/btanasa/Geneformer/geneformer/token_dictionary_gc104M.pkl",

    "target_size": 10000,  # Set to None to use full dataset
    "random_state": 73,

    # Model configuration
    "model_version": "V2",
    "freeze_layers": 2,
    "forward_batch_size": 200,
    "nproc": 10, #

    # Output
    "output_prefix": "hypoxia_2000cells_ISP"
}

# %%
# =============================================================================
# SETUP AND VERIFICATION
# =============================================================================

print("🚀 Starting Hypoxia Geneformer ISP Pipeline")
print("=" * 60)

# Create timestamped output directory
current_date = datetime.datetime.now()
datestamp = f"{str(current_date.year)[-2:]}{current_date.month:02d}{current_date.day:02d}{current_date.hour:02d}{current_date.minute:02d}{current_date.second:02d}"
datestamp_min = f"{str(current_date.year)[-2:]}{current_date.month:02d}{current_date.day:02d}"

output_dir = f"/mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/{datestamp}"
os.makedirs(output_dir, exist_ok=True)

print(f"📁 Output directory: {output_dir}")
print(f"📅 Timestamp: {datestamp}")

# Verify all required files exist
print(f"\n🔍 Verifying files...")
required_files = [
    ("Input dataset", CONFIG["input_data_file"]),
    ("Model directory", CONFIG["model_path"]),
    ("Token dictionary", CONFIG["token_dictionary_file"])
]

for name, path in required_files:
    if os.path.exists(path):
        print(f"✅ {name}: {path}")
    else:
        print(f"❌ {name}: {path}")
        print(f"   File not found - please check the path")
        # exit()
# Out:
# 🚀 Starting Hypoxia Geneformer ISP Pipeline
# ============================================================
# 📁 Output directory: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025
# 📅 Timestamp: 250827150025
#
# 🔍 Verifying files...
# ✅ Input dataset: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.dataset
# ✅ Model directory: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_out/250821141257/250821_geneformer_cellClassifier_hypoxia_condition_classifier_optimized/ksplit1/checkpoint-1400/
# ✅ Token dictionary: /mnt/nfs/CX000008_DS1/projects/btanasa/Geneformer/geneformer/token_dictionary_gc104M.pkl

# %%
# === condition ===
# Unique (3): ['2mo_HIE', '5d_HIE', 'non-HIE']

# Counts: condition
# 5d_HIE     60633
# non-HIE    25118
# 2mo_HIE    18687

print(output_dir)

# 🔬 Unique cell types: 8
# class
# Astroglia                615
# Imm-MGE                  272
# Inh-Injured              241
# Medium-Spiny-Neuron_?    207
# activated-NSCs           178
# Imm-CGE                  165
# Myelinating-Olig         164
# OPC                      158
# Out:
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025

# %%
import time

try:
    from geneformer import EmbExtractor

    # Define perturbation parameters
    cell_states_to_model = {
        "state_key": "condition",
        "start_state": "5d_HIE",
        "goal_state": "non-HIE",
        "alt_states": ["2mo_HIE"]
    }

    # Use all disease states (no filtering)
    
    # filter_data_dict = None
    # filter_data_dict = {"class":["OPC"]}
    # filter_data_dict={"class":["Astroglia"]} 
    # filter_data_dict={"class":["Imm-MGE"]} 
    filter_data_dict={"class":["Imm-CGE"]} 
    # filter_data_dict={"class":["Astroglia","Imm-MGE","Imm-CGE"]} 

    print(f"Perturbation goal: 5d_HIE → non-HIE (with 2mo_HIE as alternative)")
    print(f"Cell states: {cell_states_to_model}")
 
    # Setup embedding extractor
    print(f"🔧 Initializing embedding extractor...")
    embex = EmbExtractor(
        model_type = "CellClassifier", 
        num_classes = 3,
        filter_data = filter_data_dict,
        max_ncells = 1000,  # maximum number of cells to use 
        emb_layer = 0,
        summary_stat = "exact_mean",
        forward_batch_size = 16, # 256 in the tutorial
        model_version = "V2",
        nproc = 20, # 1
        emb_mode = "cls"             # <-- ADD for V2
        # cell_emb_style="mean_pool" # <-- REMOVE in CLS mode
    )

     # Get state embeddings with timing
    print(f"📊 Extracting state embeddings...")
    start_time = time.time()
    
    # Get state embeddings
    print(f"📊 Extracting state embeddings...")
    state_embs_dict = embex.get_state_embs(
        cell_states_to_model,
        CONFIG["model_path"],
        CONFIG["input_data_file"],
        output_dir,
        CONFIG["output_prefix"]
    )
    print(f"✅ State embeddings extracted")

    end_time = time.time()
    execution_time = end_time - start_time
    
    print(f"✅ State embeddings extracted")
    print(f"⏱️ Execution time: {execution_time:.2f} seconds ({execution_time/60:.2f} minutes)")

except Exception as e:
    print(f"❌ State embedding extraction failed: {e}")
    print(f"   Cannot proceed without state embeddings")
    import traceback
    traceback.print_exc()
    # exit()
# Out:
# Perturbation goal: 5d_HIE → non-HIE (with 2mo_HIE as alternative)
# Cell states: {'state_key': 'condition', 'start_state': '5d_HIE', 'goal_state': 'non-HIE', 'alt_states': ['2mo_HIE']}
# 🔧 Initializing embedding extractor...
# 📊 Extracting state embeddings...
# 📊 Extracting state embeddings...
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ State embeddings extracted
# ✅ State embeddings extracted
# ⏱️ Execution time: 37.66 seconds (0.63 minutes)

# %%
print(output_dir)
print(CONFIG["output_prefix"])
print(CONFIG["input_data_file"])
# Out:
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025
# hypoxia_2000cells_ISP
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.dataset

# %%
import pickle
import numpy as np

# Reconstruct the pickle filename
pkl_file = os.path.join(output_dir, f"{CONFIG['output_prefix']}.pkl")

print(f"📁 Output directory: {output_dir}")
print(f"🏷️ Output prefix: {CONFIG['output_prefix']}")
print(f"📄 Reconstructed pickle file: {pkl_file}")

# Check if the file exists
if os.path.exists(pkl_file):
    print(f"✅ File exists: {pkl_file}")
else:
    print(f"❌ File does NOT exist: {pkl_file}")


# Load the file
with open(pkl_file, 'rb') as f:
    data = pickle.load(f)

# Show what's inside
print("Keys:", list(data.keys()))
print("Number of states:", len(data))

# Show details for each state
for state, emb in data.items():
    print(f"\n{state}:")
    print(f"  Type: {type(emb)}")
    
    # Convert to numpy if it's a tensor
    if hasattr(emb, 'detach'):
        emb_array = emb.detach().cpu().numpy()
    else:
        emb_array = np.array(emb)
    
    print(f"  Shape: {emb_array.shape}")
    print(f"  First 5 values: {emb_array.flatten()[:10]}")

# Show size of each vector
for state, emb in data.items():
    print(f"{state}: {emb.shape}")

# So when you see:
emb_array.flatten()[:5]
# Out:
# 📁 Output directory: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025
# 🏷️ Output prefix: hypoxia_2000cells_ISP
# 📄 Reconstructed pickle file: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/hypoxia_2000cells_ISP.pkl
# ✅ File exists: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/hypoxia_2000cells_ISP.pkl
# Keys: ['5d_HIE', 'non-HIE', '2mo_HIE']
# Number of states: 3
#
# 5d_HIE:
#   Type: <class 'torch.Tensor'>
#   Shape: (768,)
#   First 5 values: [ 1.3388629   0.11047328 -0.00881767  0.27245227 -1.8886582  -0.3687858
#  -0.37552822 -2.0133827  -0.2290288   1.1526303 ]
#
# non-HIE:
#   Type: <class 'torch.Tensor'>
#   Shape: (768,)
#   First 5 values: [-0.5596575   0.01200579  1.2348256  -0.42618027 -0.03387723 -0.6192773
#   0.3874297  -0.07119942 -1.1508648  -0.09473387]
#
# 2mo_HIE:
#   Type: <class 'torch.Tensor'>
#   Shape: (768,)
#   First 5 values: [-0.4806132   0.82642305 -0.81911755  0.01977921  1.8138907   0.14065054
#   0.16576585  2.0762193   0.18366449 -1.1067622 ]
# 5d_HIE: torch.Size([768])
# non-HIE: torch.Size([768])
# 2mo_HIE: torch.Size([768])
# array([-0.4806132 ,  0.82642305, -0.81911755,  0.01977921,  1.8138907 ],
#       dtype=float32)

# %%
#

# %%
print("The analysis on the state embeddings:")

# STEP 1 — Imports

import os, json, time
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# STEP 2 — Prepare paths/names

prefix = f"{CONFIG['output_prefix']}_states"
emb_dir = Path(output_dir) / "state_embeddings"
emb_dir.mkdir(parents=True, exist_ok=True)

# Normalize embeddings to CPU NumPy (2D arrays)
import torch
import numpy as np
import pandas as pd
from pathlib import Path

prefix = f"{CONFIG['output_prefix']}_states"
emb_dir = Path(output_dir) / "state_embeddings"
emb_dir.mkdir(parents=True, exist_ok=True)

state_np = {}
for state, arr in state_embs_dict.items():
    # Convert possible Torch tensors (GPU or CPU) to NumPy
    if isinstance(arr, torch.Tensor):
        A = arr.detach().cpu().numpy()
    elif isinstance(arr, (list, tuple)) and len(arr) > 0 and isinstance(arr[0], torch.Tensor):
        A = torch.stack(arr).detach().cpu().numpy()
    else:
        A = np.asarray(arr)

    # Ensure 2D shape
    if A.ndim == 1:
        A = A.reshape(1, -1)

    state_np[state] = A

# STEP 3 — Save each state's embeddings to .npy and .csv 

for state, A in state_np.items():
    np.save(emb_dir / f"{prefix}_{state}.npy", A)
    pd.DataFrame(A).to_csv(emb_dir / f"{prefix}_{state}.csv", index=False)
print("Saved per-state embeddings.")

# STEP 4 — Build combined matrix + labels; save
X_list, labels = [], []
for state, A in state_np.items():
    X_list.append(A)
    labels += [state] * A.shape[0]

X = np.vstack(X_list)
combined = pd.DataFrame(X)
combined["state"] = labels
np.save(emb_dir / f"{prefix}_all.npy", X)
combined.to_csv(emb_dir / f"{prefix}_all.csv", index=False)
print("Saved combined embeddings.")

# STEP 5 — Cosine-similarity heatmap of STATE MEANS
import matplotlib.pyplot as plt

states = list(state_np.keys())
means = np.stack([A.mean(axis=0) for A in state_np.values()], axis=0)

# cosine similarity without external deps
norms = np.linalg.norm(means, axis=1, keepdims=True) + 1e-12
C = (means / norms) @ (means / norms).T

plt.figure(figsize=(4, 3))
im = plt.imshow(C, vmin=0, vmax=1)
plt.xticks(range(len(states)), states, rotation=45, ha="right")
plt.yticks(range(len(states)), states)
plt.title("Cosine similarity of state means")
plt.colorbar(im, fraction=0.046, pad=0.04)
plt.tight_layout()
plt.savefig(emb_dir / f"{prefix}_cosine_heatmap.png", dpi=200)
plt.close()
print("Saved cosine-similarity heatmap.")

# STEP 6 — PCA scatter 

from IPython.display import display
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

if X.shape[0] >= 3:
    pca = PCA(n_components=2, random_state=73)
    Xp = pca.fit_transform(X)

    # Plot (SHOW + save)
    plt.figure(figsize=(5, 4))
    for s in sorted(set(labels)):
        m = (np.array(labels) == s)
        plt.scatter(Xp[m, 0], Xp[m, 1], s=8, alpha=0.7, label=s)
    plt.legend()
    plt.title("PCA of embeddings")
    plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% var)")
    plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% var)")
    plt.tight_layout()
    plt.show()  # ⬅️ display inline
    plt.savefig(emb_dir / f"{prefix}_pca.png", dpi=200)
    plt.close()

    # Save coordinates + preview
    pca_df = pd.DataFrame({"PC1": Xp[:, 0], "PC2": Xp[:, 1], "state": labels})
    pca_df.to_csv(emb_dir / f"{prefix}_pca.csv", index=False)
    np.save(emb_dir / f"{prefix}_pca.npy", Xp)
    print("PCA coords saved. Preview:")
    display(pca_df.head())
else:
    print("Skipped PCA: need ≥3 rows in X.")
# Out:
# The analysis on the state embeddings:
# Saved per-state embeddings.
# Saved combined embeddings.
# Saved cosine-similarity heatmap.
# PCA coords saved. Preview:
#          PC1        PC2    state
# 0 -25.308901  -5.917567   5d_HIE
# 1  18.128714 -17.560009  non-HIE
# 2   7.180184  23.477577  2mo_HIE

# %%
# create the output files 

try:
    with open(CONFIG["token_dictionary_file"], "rb") as f:
        tok = pickle.load(f)
    keys = set(tok.keys()) if isinstance(tok, dict) else set()
    vals = set(tok.values()) if isinstance(tok, dict) else set()
    missing = [g for g in genes_to_perturb if g not in keys and g not in vals]
    if missing:
        print("⚠️ WARNING: not found in token dictionary:", missing)
except Exception as e:
    print("ℹ️ Skipping token-dict validation:", e)

# Output folders
isp_output_dir = os.path.join(output_dir, "isp")
isp_stats_dir  = os.path.join(output_dir, "isp_stats")
os.makedirs(isp_output_dir, exist_ok=True)
os.makedirs(isp_stats_dir, exist_ok=True)
# Out:
# ℹ️ Skipping token-dict validation: name 'genes_to_perturb' is not defined

# %%
# Your genes list
GENES = [
    "ENSG00000041415", "ENSG00000183098", "ENSG00000089225", "ENSG00000081189",
    "ENSG00000118058", "ENSG00000164199", "ENSG00000112658", "ENSG00000126353",
    "ENSG00000054598", "ENSG00000052904", "ENSG00000150907", "ENSG00000118689",
    "ENSG00000131196", "ENSG00000101096", "ENSG00000101097", "ENSG00000109320",
    "ENSG00000173039", "ENSG00000177606", "ENSG00000170345", "ENSG00000135917",
    "ENSG00000115414", "ENSG00000164093", "ENSG00000186951", "ENSG00000132170",
    "ENSG00000106462", "ENSG00000116044", "ENSG00000175387", "ENSG00000166949",
    "ENSG00000141646", "ENSG00000122691", "ENSG00000124216", "ENSG00000136826",
    "ENSG00000102554", "ENSG00000092929", "ENSG00000069592", "ENSG00000118526"
]

# To get valid TFs:
valid_GENES = set(token_df["Ensembl_ID"]).intersection(GENES)
print(f"✅ Valid GENES: {len(valid_GENES)}")
print(f"�� Use: {list(valid_GENES)}")

genes_to_perturb = valid_GENES
print(valid_GENES)

# genes_raw = genes_to_perturb
# genes_to_perturb = genes_raw
genes_raw = valid_GENES
print(genes_raw)
# Out:
# ✅ Valid GENES: 32
# �� Use: ['ENSG00000112658', 'ENSG00000106462', 'ENSG00000126353', 'ENSG00000175387', 'ENSG00000164199', 'ENSG00000135917', 'ENSG00000081189', 'ENSG00000141646', 'ENSG00000054598', 'ENSG00000109320', 'ENSG00000186951', 'ENSG00000124216', 'ENSG00000173039', 'ENSG00000092929', 'ENSG00000132170', 'ENSG00000102554', 'ENSG00000116044', 'ENSG00000164093', 'ENSG00000183098', 'ENSG00000122691', 'ENSG00000118526', 'ENSG00000118058', 'ENSG00000150907', 'ENSG00000177606', 'ENSG00000170345', 'ENSG00000089225', 'ENSG00000115414', 'ENSG00000131196', 'ENSG00000118689', 'ENSG00000101096', 'ENSG00000166949', 'ENSG00000136826']
# {'ENSG00000112658', 'ENSG00000106462', 'ENSG00000126353', 'ENSG00000175387', 'ENSG00000164199', 'ENSG00000135917', 'ENSG00000081189', 'ENSG00000141646', 'ENSG00000054598', 'ENSG00000109320', 'ENSG00000186951', 'ENSG00000124216', 'ENSG00000173039', 'ENSG00000092929', 'ENSG00000132170', 'ENSG00000102554', 'ENSG00000116044', 'ENSG00000164093', 'ENSG00000183098', 'ENSG00000122691', 'ENSG00000118526', 'ENSG00000118058', 'ENSG00000150907', 'ENSG00000177606', 'ENSG00000170345', 'ENSG00000089225', 'ENSG00000115414', 'ENSG00000131196', 'ENSG00000118689', 'ENSG00000101096', 'ENSG00000166949', 'ENSG00000136826'}
# {'ENSG00000112658', 'ENSG00000106462', 'ENSG00000126353', 'ENSG00000175387', 'ENSG00000164199', 'ENSG00000135917', 'ENSG00000081189', 'ENSG00000141646', 'ENSG00000054598', 'ENSG00000109320', 'ENSG00000186951', 'ENSG00000124216', 'ENSG00000173039', 'ENSG00000092929', 'ENSG00000132170', 'ENSG00000102554', 'ENSG00000116044', 'ENSG00000164093', 'ENSG00000183098', 'ENSG00000122691', 'ENSG00000118526', 'ENSG00000118058', 'ENSG00000150907', 'ENSG00000177606', 'ENSG00000170345', 'ENSG00000089225', 'ENSG00000115414', 'ENSG00000131196', 'ENSG00000118689', 'ENSG00000101096', 'ENSG00000166949', 'ENSG00000136826'}

# %%
# genes_raw = ['ENSG00000136574', 'ENSG00000183098', 'ENSG00000089225'] 
genes_raw = ["ENSG00000186951", "ENSG00000116044", "ENSG00000081189"]
genes_raw = [str(gene).strip() for gene in genes_raw]
print("Genes to perturb:", genes_raw)
# Out:
# Genes to perturb: ['ENSG00000186951', 'ENSG00000116044', 'ENSG00000081189']

# %%
##########################################################################################
##########################################################################################
# Target genes (Ensembl IDs) 
# genes_raw = ["ENSG00000186951", "ENSG00000116044", "ENSG00000081189"]

# Verify the genes
for gene in genes_raw:
    if gene in token_dict:
        token_id = token_dict[gene]
        print(f"✅ {gene} -> {token_id} ({type(token_id)})")
    else:
        print(f"❌ {gene} not found in token dictionary")

        
def strip_ver(x):  # ENSG00000123456.12 -> ENSG00000123456
    return x.split('.')[0]

# --- Load token dictionary
import pickle
with open(CONFIG["token_dictionary_file"], "rb") as f:
    token_dict = pickle.load(f)  # maps Ensembl (or symbols) -> token_id

# --- Data cleaning and verify with the token dict
genes_norm = [strip_ver(g) for g in genes_raw]
missing_in_dict = [g for g in genes_norm if g not in token_dict]
if missing_in_dict:
    raise RuntimeError(
        f"The following Ensembl IDs are not in the token dictionary: {missing_in_dict}\n"
        "→ Use a matching token_dictionary_file or retokenize."
    )

# --- Map Ensembl -> token ids
id2tok = {g: token_dict[g] for g in genes_norm}

# --- Verify these genes actually appear in the dataset (at least one cell)
from datasets import load_from_disk
dataset = load_from_disk(CONFIG["input_data_file"])

present_counts = {g: 0 for g in id2tok}
for ids in dataset["input_ids"]:
    s = set(ids)
    for g, t in id2tok.items():
        if t in s:
            present_counts[g] += 1

print("Cells containing each target gene:", present_counts)

genes_to_perturb = [g for g, cnt in present_counts.items() if cnt > 100] # number of cells higher than 10
if not genes_to_perturb:
    raise RuntimeError(
        "None of the requested genes appear in any cell; nothing to perturb.\n"
        "→ Pick more frequent genes or retokenize with a longer sequence length."
    )

print("Using genes_to_perturb =", genes_to_perturb)
# Out:
# ✅ ENSG00000186951 -> 15606 (<class 'int'>)
# ✅ ENSG00000116044 -> 4487 (<class 'int'>)
# ✅ ENSG00000081189 -> 1524 (<class 'int'>)
# Cells containing each target gene: {'ENSG00000186951': 337, 'ENSG00000116044': 551, 'ENSG00000081189': 859}
# Using genes_to_perturb = ['ENSG00000186951', 'ENSG00000116044', 'ENSG00000081189']

# %%
# print(dataset["input_ids"])
print(CONFIG["input_data_file"])

# Output folders
isp_output_dir = os.path.join(output_dir, "isp")
isp_stats_dir  = os.path.join(output_dir, "isp_stats")
os.makedirs(isp_output_dir, exist_ok=True)
os.makedirs(isp_stats_dir, exist_ok=True)
# Out:
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.dataset

# %%
# === Geneformer ===
from geneformer import EmbExtractor, Classifier, InSilicoPerturber, InSilicoPerturberStats
import pickle

# %%
# genes_to_perturb = ['ENSG00000081189', 'ENSG00000186951', 'ENSG00000116044', 'ENSG00000115414', 'ENSG00000175387', 'ENSG00000164199', 'ENSG00000106462', 'ENSG00000141646', 'ENSG00000170345', 'ENSG00000118689', 'ENSG00000109320', 'ENSG00000102554', 'ENSG00000118058', 'ENSG00000150907', 'ENSG00000134954']

# %%
print(f"🧬 Starting ISP analysis for {len(genes_to_perturb)} genes...")
print("=" * 60)

# Track results and errors
successful_genes = []
failed_genes = []
total_start_time = time.time()

for i, gene in enumerate(genes_to_perturb, 1):
    print(f"\n Processing gene {i}/{len(genes_to_perturb)}: {gene}")
    print("-" * 50)
    
    try:
        # Time the ISP initialization for this gene
        print(f" Initializing InSilicoPerturber for {gene}...")
        init_start = time.time()
        
        isp = InSilicoPerturber(
            perturb_type="delete",
            perturb_rank_shift=None,
            genes_to_perturb=[gene],  # Single gene
            combos=0,
            anchor_gene=None,
            model_type="CellClassifier",
            num_classes=3,
            emb_mode="cls",
            filter_data=filter_data_dict,
            cell_states_to_model=cell_states_to_model,
            state_embs_dict=state_embs_dict,
            max_ncells=1200,
            emb_layer=0,
            forward_batch_size=32,
            model_version="V2",
            nproc=10
        )
        
        init_time = time.time() - init_start
        print(f"✅ ISP initialized for {gene} in {init_time:.2f} seconds")
        
        # Time the perturbation execution for this gene
        print(f"🧬 Running ISP perturbation for {gene}...")
        perturb_start = time.time()
        
        # Create gene-specific output directory
        gene_output_dir = os.path.join(isp_output_dir, f"gene_{gene}")
        gene_stats_dir = os.path.join(isp_stats_dir, f"gene_{gene}")
        os.makedirs(gene_output_dir, exist_ok=True)
        os.makedirs(gene_stats_dir, exist_ok=True)
        
        isp.perturb_data(
            CONFIG["model_path"],
            CONFIG["input_data_file"],
            gene_output_dir,
            f"{CONFIG['output_prefix']}_{gene}"
        )
        
        perturb_time = time.time() - perturb_start
        total_time = time.time() - init_start
        
        print(f"✅ ISP outputs for {gene} -> {gene_output_dir}")
        print(f"⏱️ Perturbation time for {gene}: {perturb_time:.2f} seconds ({perturb_time/60:.2f} minutes)")
        print(f"⏱️ Total time for {gene}: {total_time:.2f} seconds ({total_time/60:.2f} minutes)")
        
        # Goal-state-shift statistics for this gene
        print(f" Initializing InSilicoPerturberStats for {gene}...")
        stats_init_start = time.time()
        
        ispstats = InSilicoPerturberStats(
            mode="goal_state_shift",
            genes_perturbed=[gene],
            combos=0,
            anchor_gene=None,
            cell_states_to_model=cell_states_to_model,
            model_version="V2",
            token_dictionary_file=token_dictionary_file
        )

        stats_init_time = time.time() - stats_init_start
        total_time_with_stats = time.time() - init_start
        
        print(f"✅ InSilicoPerturberStats initialized for {gene} in {stats_init_time:.2f} seconds")
        print(f"⏱️ Total time for {gene} (init + execution + stats_init): {total_time_with_stats:.2f} seconds ({total_time_with_stats/60:.2f} minutes)")
        
        # Time the statistics computation for this gene
        print(f"📈 Computing statistics for {gene}...")
        stats_comp_start = time.time()
        
        ispstats.get_stats(
            gene_output_dir,  # Use gene-specific output directory
            None,
            gene_stats_dir,   # Use gene-specific stats directory
            f"{CONFIG['output_prefix']}_{gene}"
        )
        
        stats_comp_time = time.time() - stats_comp_start
        total_gene_time = time.time() - init_start
        
        print(f"✅ Statistics computed for {gene} -> {gene_stats_dir}")
        print(f"⏱️ Statistics computation time for {gene}: {stats_comp_time:.2f} seconds ({stats_comp_time/60:.2f} minutes)")
        print(f"⏱️ Total time for {gene}: {total_gene_time:.2f} seconds ({total_gene_time/60:.2f} minutes)")
        
        # Mark as successful
        successful_genes.append(gene)
        print(f"✅ Gene {gene} completed successfully!")
        
    except Exception as e:
        # Enhanced error logging with line numbers
        import traceback
        error_msg = f"❌ Error processing gene {gene}: {str(e)}"
        print(error_msg)
        print("Full error traceback:")
        traceback.print_exc()
        
        # Log to file
        log_file = os.path.join(output_dir, "gene_processing_errors.log")
        with open(log_file, 'a') as f:
            timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            f.write(f"[{timestamp}] {error_msg}\n")
            f.write(f"Traceback:\n{traceback.format_exc()}\n")
        
        failed_genes.append(gene)
        print(f"⚠️ Continuing with next gene...")
        continue

# Final summary
total_end_time = time.time()
total_elapsed = total_end_time - total_start_time

print("\n" + "=" * 60)
print("🏁 GENE PROCESSING SUMMARY")
print("=" * 60)
print(f"📊 Total genes processed: {len(genes_to_perturb)}")
print(f"✅ Successful genes: {len(successful_genes)}")
print(f"❌ Failed genes: {len(failed_genes)}")
print(f"⏱️ Total elapsed time: {total_elapsed:.2f} seconds ({total_elapsed/60:.2f} minutes)")

if failed_genes:
    print(f"\n❌ Failed genes:")
    for gene in failed_genes:
        print(f"  - {gene}")
    
    print(f"\n Check error log: {os.path.join(output_dir, 'gene_processing_errors.log')}")
# Out:
# 🧬 Starting ISP analysis for 3 genes...
# ============================================================
#
#  Processing gene 1/3: ENSG00000186951
# --------------------------------------------------
#  Initializing InSilicoPerturber for ENSG00000186951...
# ✅ ISP initialized for ENSG00000186951 in 0.00 seconds
# 🧬 Running ISP perturbation for ENSG00000186951...
# num_proc must be <= 5. Reducing num_proc to 5 for dataset of size 5.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ ISP outputs for ENSG00000186951 -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp/gene_ENSG00000186951
# ⏱️ Perturbation time for ENSG00000186951: 32.09 seconds (0.53 minutes)
# ⏱️ Total time for ENSG00000186951: 32.09 seconds (0.53 minutes)
#  Initializing InSilicoPerturberStats for ENSG00000186951...
# ✅ InSilicoPerturberStats initialized for ENSG00000186951 in 0.01 seconds
# ⏱️ Total time for ENSG00000186951 (init + execution + stats_init): 32.10 seconds (0.54 minutes)
# 📈 Computing statistics for ENSG00000186951...
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Statistics computed for ENSG00000186951 -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp_stats/gene_ENSG00000186951
# ⏱️ Statistics computation time for ENSG00000186951: 0.01 seconds (0.00 minutes)
# ⏱️ Total time for ENSG00000186951: 32.12 seconds (0.54 minutes)
# ✅ Gene ENSG00000186951 completed successfully!
#
#  Processing gene 2/3: ENSG00000116044
# --------------------------------------------------
#  Initializing InSilicoPerturber for ENSG00000116044...
# ✅ ISP initialized for ENSG00000116044 in 0.00 seconds
# 🧬 Running ISP perturbation for ENSG00000116044...
# num_proc must be <= 2. Reducing num_proc to 2 for dataset of size 2.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ ISP outputs for ENSG00000116044 -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp/gene_ENSG00000116044
# ⏱️ Perturbation time for ENSG00000116044: 17.31 seconds (0.29 minutes)
# ⏱️ Total time for ENSG00000116044: 17.32 seconds (0.29 minutes)
#  Initializing InSilicoPerturberStats for ENSG00000116044...
# ✅ InSilicoPerturberStats initialized for ENSG00000116044 in 0.01 seconds
# ⏱️ Total time for ENSG00000116044 (init + execution + stats_init): 17.33 seconds (0.29 minutes)
# 📈 Computing statistics for ENSG00000116044...
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Statistics computed for ENSG00000116044 -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp_stats/gene_ENSG00000116044
# ⏱️ Statistics computation time for ENSG00000116044: 0.01 seconds (0.00 minutes)
# ⏱️ Total time for ENSG00000116044: 17.34 seconds (0.29 minutes)
# ✅ Gene ENSG00000116044 completed successfully!
#
#  Processing gene 3/3: ENSG00000081189
# --------------------------------------------------
#  Initializing InSilicoPerturber for ENSG00000081189...
# ✅ ISP initialized for ENSG00000081189 in 0.00 seconds
# 🧬 Running ISP perturbation for ENSG00000081189...
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ ISP outputs for ENSG00000081189 -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp/gene_ENSG00000081189
# ⏱️ Perturbation time for ENSG00000081189: 56.07 seconds (0.93 minutes)
# ⏱️ Total time for ENSG00000081189: 56.07 seconds (0.93 minutes)
#  Initializing InSilicoPerturberStats for ENSG00000081189...
# ✅ InSilicoPerturberStats initialized for ENSG00000081189 in 0.01 seconds
# ⏱️ Total time for ENSG00000081189 (init + execution + stats_init): 56.09 seconds (0.93 minutes)
# 📈 Computing statistics for ENSG00000081189...
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Statistics computed for ENSG00000081189 -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp_stats/gene_ENSG00000081189
# ⏱️ Statistics computation time for ENSG00000081189: 0.01 seconds (0.00 minutes)
# ⏱️ Total time for ENSG00000081189: 56.10 seconds (0.93 minutes)
# ✅ Gene ENSG00000081189 completed successfully!
#
# ============================================================
# 🏁 GENE PROCESSING SUMMARY
# ============================================================
# 📊 Total genes processed: 3
# ✅ Successful genes: 3
# ❌ Failed genes: 0
# ⏱️ Total elapsed time: 105.56 seconds (1.76 minutes)

# %%
# Examine the pickle files : to fix !!

# %%
print(isp_output_dir)
# Out:
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp

# %%
# Do not run it yet !

# %%
# the old code to run transcriptome-wide ISP

# %%
print(output_dir)
print(isp_output_dir)
print(isp_stats_dir)
# Out:
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp
# /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp_stats

# %%
genes_to_perturb = "all"

import time

# Time the ISP initialization
print("�� Initializing InSilicoPerturber...")
init_start = time.time()

isp = InSilicoPerturber(
    perturb_type = "delete",
    perturb_rank_shift = None,
    genes_to_perturb = genes_to_perturb,
    # genes_to_perturb = "all",
    combos = 0,
    anchor_gene = None,
    model_type = "CellClassifier",
    num_classes = 3,
    emb_mode = "cls",                     # ✅ Use CLS embedding for V2
    # emb_mode = "cell",                    # SET TO "CELL" FOR V1 MODEL. FOR V2, SHOULD BE "CLS" (current default).
    # emb_mode = "cls_and_gene",
    filter_data = filter_data_dict,
    cell_states_to_model = cell_states_to_model,
    state_embs_dict = state_embs_dict,
    max_ncells = 1200,
    emb_layer = 0,
    forward_batch_size = 32,
    model_version = "V2",                 # ✅ Matches CLS usage
    nproc = 130
)

# --- avoid the Column * int bug by skipping the special-token code path ---
if hasattr(isp, "special_token"):
    isp.special_token = False

# Time the perturbation execution
print("🧬 Running ISP perturbation...")
perturb_start = time.time()

isp.perturb_data(
    CONFIG["model_path"],
    CONFIG["input_data_file"],
    isp_output_dir,
    f"{CONFIG['output_prefix']}_tf"
)

perturb_time = time.time() - perturb_start
total_time = time.time() - init_start

print(f"✅ ISP outputs -> {isp_output_dir}")
print(f"⏱️ Perturbation execution time: {perturb_time:.2f} seconds ({perturb_time/60:.2f} minutes)")
print(f"⏱️ Total time (init + execution): {total_time:.2f} seconds ({total_time/60:.2f} minutes)")

# Goal-state-shift statistics (Chronic → Normoxia, Acute as alt)
print("�� Initializing InSilicoPerturberStats...")
stats_init_start = time.time()

ispstats = InSilicoPerturberStats(
    mode="goal_state_shift",
    genes_perturbed = genes_to_perturb,
    combos = 0,
    anchor_gene = None,
    cell_states_to_model = cell_states_to_model,
    model_version = "V2",
    token_dictionary_file = token_dictionary_file
)

stats_init_time = time.time() - stats_init_start
total_time_with_stats = time.time() - init_start

print(f"✅ InSilicoPerturberStats initialized in {stats_init_time:.2f} seconds")
print(f"⏱️ Total time (init + execution + stats_init): {total_time_with_stats:.2f} seconds ({total_time_with_stats/60:.2f} minutes)")

# Time the statistics computation
print("📈 Computing statistics...")
stats_comp_start = time.time()

ispstats.get_stats(
    isp_output_dir,
    None,
    isp_stats_dir,
    f"{CONFIG['output_prefix']}_genes"
)

stats_comp_time = time.time() - stats_comp_start

print(f"✅ Statistics computed -> {isp_stats_dir}")
print(f"⏱️ Statistics computation time: {stats_comp_time:.2f} seconds ({stats_comp_time/60:.2f} minutes)")
# Out:
# �� Initializing InSilicoPerturber...
# 🧬 Running ISP perturbation...
#   0%|          | 0/83 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/128 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/128 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/128 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/122 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/120 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/116 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/114 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/112 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/111 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/104 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/96 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/34 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/33 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/30 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/27 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ ISP outputs -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp
# ⏱️ Perturbation execution time: 29892.68 seconds (498.21 minutes)
# ⏱️ Total time (init + execution): 29892.69 seconds (498.21 minutes)
# �� Initializing InSilicoPerturberStats...
# ✅ InSilicoPerturberStats initialized in 0.02 seconds
# ⏱️ Total time (init + execution + stats_init): 29892.70 seconds (498.21 minutes)
# 📈 Computing statistics...
#   0%|          | 0/169 [00:00<?, ?it/s]
#   0%|          | 0/12196 [00:00<?, ?it/s]
#   0%|          | 0/12196 [00:00<?, ?it/s]
# ✅ Statistics computed -> /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp_stats
# ⏱️ Statistics computation time: 543.52 seconds (9.06 minutes)

# %%
# After ISP execution, automatically load results from isp_output_dir
print(f"📁 Loading ISP results from: {isp_output_dir}")

# Look for pickle files in the isp_output_dir
import glob
pickle_files = glob.glob(os.path.join(isp_output_dir, "*_raw.pickle"))

if pickle_files:
    # Use the most recent file (in case there are multiple)
    latest_pickle = max(pickle_files, key=os.path.getctime)
    print(f"✅ Found ISP results: {os.path.basename(latest_pickle)}")
    
    # Load automatically
    with open(latest_pickle, 'rb') as f:
        data = pickle.load(f)
    
    print(f"\n📊 File contents:")
    print(f"Type: {type(data)}")
    
    if isinstance(data, dict):
        print(f"Keys: {list(data.keys())}")
        
        # Explore the structure
        for key, value in data.items():
            print(f"\n--- {key} ---")
            print(f"  Type: {type(value)}")
            
            if isinstance(value, dict):
                print(f"  Dict keys: {list(value.keys())}")
                for sub_key, sub_value in value.items():
                    print(f"    {sub_key}: {type(sub_value)}")
                    if hasattr(sub_value, 'shape'):
                        print(f"      Shape: {sub_value.shape}")
                    elif isinstance(sub_value, list):
                        print(f"      Length: {len(sub_value)}")
                        print(f"      First 5 values: {sub_value[:5]}")
            elif hasattr(value, 'shape'):
                print(f"  Shape: {value.shape}")
            elif isinstance(value, list):
                print(f"  Length: {len(value)}")
                print(f"  First 10 values: {value[:10]}")
                print(f"  Last 5 values: {value[-5:]}")
    else:
        print(f"Content: {data}")
    
    # Store in perturbation_results for later use
    perturbation_results = data
    print(f"\n🎯 Results loaded into 'perturbation_results' variable!")
    
else:
    print(f"❌ No ISP results found in {isp_output_dir}")
    print(f"Available files:")
    for f in sorted(os.listdir(isp_output_dir)):
        print(f"  {f}")
    perturbation_results = None
# Out:
# 📁 Loading ISP results from: /mnt/nfs/CX000008_DS1/projects/btanasa/hypoxia/test_geneformer_5_full_h5ad_aug20_subsample2000cells_dataset_oldlabel.isp/250827150025/isp
# ✅ Found ISP results: in_silico_delete_hypoxia_2000cells_ISP_tf_dict_cell_embs_82batch0_raw.pickle
#
# 📊 File contents:
# Type: <class 'dict'>
# Keys: ['5d_HIE', 'non-HIE', '2mo_HIE']
#
# --- 5d_HIE ---
#   Type: <class 'collections.defaultdict'>
#   Dict keys: [(7160, 'cell_emb'), (8816, 'cell_emb'), (2800, 'cell_emb'), (15017, 'cell_emb'), (5665, 'cell_emb'), (9923, 'cell_emb'), (8207, 'cell_emb'), (5374, 'cell_emb'), (8087, 'cell_emb'), (5257, 'cell_emb'), (13685, 'cell_emb'), (15074, 'cell_emb'), (16281, 'cell_emb'), (19639, 'cell_emb'), (7561, 'cell_emb'), (229, 'cell_emb'), (10091, 'cell_emb'), (7630, 'cell_emb'), (6092, 'cell_emb'), (335, 'cell_emb'), (6649, 'cell_emb'), (12308, 'cell_emb'), (16097, 'cell_emb'), (1327, 'cell_emb'), (4127, 'cell_emb'), (3447, 'cell_emb'), (6994, 'cell_emb'), (5595, 'cell_emb'), (7266, 'cell_emb'), (13100, 'cell_emb'), (3361, 'cell_emb'), (16040, 'cell_emb'), (18339, 'cell_emb'), (5305, 'cell_emb'), (16647, 'cell_emb'), (1064, 'cell_emb'), (9288, 'cell_emb'), (1149, 'cell_emb'), (3657, 'cell_emb'), (715, 'cell_emb'), (14093, 'cell_emb'), (11502, 'cell_emb'), (7624, 'cell_emb'), (9359, 'cell_emb'), (2200, 'cell_emb'), (9059, 'cell_emb'), (1798, 'cell_emb'), (3356, 'cell_emb'), (89, 'cell_emb'), (10093, 'cell_emb'), (12242, 'cell_emb'), (4022, 'cell_emb'), (6945, 'cell_emb'), (6133, 'cell_emb'), (12845, 'cell_emb'), (10849, 'cell_emb'), (16299, 'cell_emb'), (5069, 'cell_emb'), (9611, 'cell_emb'), (9459, 'cell_emb'), (6349, 'cell_emb'), (4178, 'cell_emb'), (10208, 'cell_emb'), (12872, 'cell_emb'), (10220, 'cell_emb'), (4177, 'cell_emb'), (7707, 'cell_emb'), (2175, 'cell_emb'), (19537, 'cell_emb'), (11306, 'cell_emb'), (2120, 'cell_emb'), (8711, 'cell_emb'), (3904, 'cell_emb'), (2873, 'cell_emb'), (11474, 'cell_emb'), (7296, 'cell_emb'), (8868, 'cell_emb'), (11612, 'cell_emb'), (2564, 'cell_emb'), (9903, 'cell_emb'), (17811, 'cell_emb'), (16405, 'cell_emb'), (6878, 'cell_emb'), (2683, 'cell_emb'), (3135, 'cell_emb'), (2431, 'cell_emb'), (15249, 'cell_emb'), (15751, 'cell_emb'), (7740, 'cell_emb'), (13065, 'cell_emb'), (2598, 'cell_emb'), (9094, 'cell_emb'), (13582, 'cell_emb'), (5635, 'cell_emb'), (2307, 'cell_emb'), (12571, 'cell_emb'), (2577, 'cell_emb'), (13144, 'cell_emb'), (9681, 'cell_emb'), (12503, 'cell_emb'), (882, 'cell_emb'), (7993, 'cell_emb'), (1732, 'cell_emb'), (1870, 'cell_emb'), (3886, 'cell_emb'), (15645, 'cell_emb'), (5877, 'cell_emb'), (10597, 'cell_emb'), (3882, 'cell_emb'), (8210, 'cell_emb'), (13677, 'cell_emb'), (10795, 'cell_emb'), (870, 'cell_emb'), (11686, 'cell_emb'), (11541, 'cell_emb'), (6874, 'cell_emb'), (3745, 'cell_emb'), (18879, 'cell_emb'), (3121, 'cell_emb'), (1616, 'cell_emb'), (7502, 'cell_emb'), (17782, 'cell_emb'), (2675, 'cell_emb'), (13193, 'cell_emb'), (6379, 'cell_emb'), (2583, 'cell_emb'), (11284, 'cell_emb'), (10082, 'cell_emb'), (11204, 'cell_emb'), (14218, 'cell_emb'), (8267, 'cell_emb'), (812, 'cell_emb'), (8614, 'cell_emb'), (13172, 'cell_emb'), (10740, 'cell_emb'), (4710, 'cell_emb'), (14265, 'cell_emb'), (12908, 'cell_emb'), (711, 'cell_emb'), (2176, 'cell_emb'), (5654, 'cell_emb'), (4623, 'cell_emb'), (1721, 'cell_emb'), (4795, 'cell_emb'), (2742, 'cell_emb'), (2701, 'cell_emb'), (8036, 'cell_emb'), (15898, 'cell_emb'), (1255, 'cell_emb'), (4667, 'cell_emb'), (11058, 'cell_emb'), (10396, 'cell_emb'), (17152, 'cell_emb'), (6190, 'cell_emb'), (10025, 'cell_emb'), (354, 'cell_emb'), (886, 'cell_emb'), (4921, 'cell_emb'), (9386, 'cell_emb'), (7672, 'cell_emb'), (3198, 'cell_emb'), (17314, 'cell_emb'), (12930, 'cell_emb'), (7437, 'cell_emb'), (18416, 'cell_emb'), (741, 'cell_emb'), (4140, 'cell_emb'), (2863, 'cell_emb'), (15940, 'cell_emb'), (3281, 'cell_emb'), (10330, 'cell_emb'), (6324, 'cell_emb'), (420, 'cell_emb'), (4546, 'cell_emb'), (18771, 'cell_emb'), (11264, 'cell_emb'), (2854, 'cell_emb'), (12141, 'cell_emb'), (12129, 'cell_emb'), (14553, 'cell_emb'), (473, 'cell_emb'), (5085, 'cell_emb'), (14471, 'cell_emb'), (3705, 'cell_emb'), (602, 'cell_emb'), (2021, 'cell_emb'), (9620, 'cell_emb'), (7638, 'cell_emb'), (9172, 'cell_emb'), (1849, 'cell_emb'), (15597, 'cell_emb'), (4745, 'cell_emb'), (6449, 'cell_emb'), (17516, 'cell_emb'), (2367, 'cell_emb'), (2629, 'cell_emb'), (10248, 'ce ...
#     (7160, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012054443359375]
#     (8816, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012298822402954102]
#     (2800, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011157393455505371]
#     (15017, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012604594230651855]
#     (5665, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001016855239868164]
#     (9923, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016625523567199707]
#     (8207, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013210177421569824]
#     (5374, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013063549995422363]
#     (8087, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014044642448425293]
#     (5257, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014432668685913086]
#     (13685, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013990998268127441]
#     (15074, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011664032936096191]
#     (16281, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014783740043640137]
#     (19639, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010538697242736816]
#     (7561, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016576647758483887]
#     (229, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014469027519226074]
#     (10091, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000994265079498291]
#     (7630, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001504361629486084]
#     (6092, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011034607887268066]
#     (335, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013331174850463867]
#     (6649, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010614991188049316]
#     (12308, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015835165977478027]
#     (16097, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001782238483428955]
#     (1327, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015303492546081543]
#     (4127, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013207793235778809]
#     (3447, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015080571174621582]
#     (6994, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001481175422668457]
#     (5595, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014491677284240723]
#     (7266, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013900399208068848]
#     (13100, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011340975761413574]
#     (3361, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001684725284576416]
#     (16040, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011882185935974121]
#     (18339, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009644031524658203]
#     (5305, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016984343528747559]
#     (16647, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010679960250854492]
#     (1064, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010430216789245605]
#     (9288, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011999011039733887]
#     (1149, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013869404792785645]
#     (3657, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014057159423828125]
#     (715, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011276602745056152]
#     (14093, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001212775707244873]
#     (11502, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012226700782775879]
#     (7624, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013236403465270996]
#     (9359, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012547969818115234]
#     (2200, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011301636695861816]
#     (9059, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011307597160339355]
#     (1798, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013341307640075684]
#     (3356, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001526176929473877]
#     (89, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014718174934387207]
#     (10093, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013182759284973145]
#     (12242, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011299848556518555]
#     (4022, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010238289833068848]
#     (6945, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010107159614562988]
#     (6133, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013055205345153809]
#     (12845, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013507604598999023]
#     (10849, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010552406311035156]
#     (16299, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000820159912109375]
#     (5069, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011722445487976074]
#     (9611, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00107574462890625]
#     (9459, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016265511512756348]
#     (6349, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012978911399841309]
#     (4178, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011647343635559082]
#     (10208, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013440251350402832]
#     (12872, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016364455223083496]
#     (10220, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013007521629333496]
#     (4177, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011461377143859863]
#     (7707, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010916590690612793]
#     (2175, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001182258129119873]
#     (19537, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013638734817504883]
#     (11306, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013440251350402832]
#     (2120, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009003281593322754]
#     (8711, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001180887222290039]
#     (3904, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0020009875297546387]
#     (2873, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001361548900604248]
#     (11474, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011404156684875488]
#     (7296, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013759136199951172]
#     (8868, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007378458976745605]
#     (11612, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016652941703796387]
#     (2564, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012134909629821777]
#     (9903, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015116333961486816]
#     (17811, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001175224781036377]
#     (16405, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014140009880065918]
#     (6878, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006985068321228027]
#     (2683, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001556694507598877]
#     (3135, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012020468711853027]
#     (2431, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013927817344665527]
#     (15249, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000880897045135498]
#     (15751, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012118220329284668]
#     (7740, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013799071311950684]
#     (13065, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008113980293273926]
#     (2598, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012806057929992676]
#     (9094, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012786388397216797]
#     (13582, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001360476016998291]
#     (5635, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013911724090576172]
#     (2307, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001472175121307373]
#     (12571, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014646649360656738]
#     (2577, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011629462242126465]
#     (13144, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013207793235778809]
#     (9681, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001332104206085205]
#     (12503, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001358330249786377]
#     (882, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013116002082824707]
#     (7993, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010851025581359863]
#     (1732, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012735724449157715]
#     (1870, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013465285301208496]
#     (3886, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012399554252624512]
#     (15645, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001325845718383789]
#     (5877, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012629032135009766]
#     (10597, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012093782424926758]
#     (3882, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014002323150634766]
#     (8210, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014914870262145996]
#     (13677, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0019657015800476074]
#     (10795, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012459158897399902]
#     (870, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001480400562286377]
#     (11686, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013824105262756348]
#     (11541, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011935234069824219]
#     (6874, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013930201530456543]
#     (3745, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012595653533935547]
#     (18879, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001135110855102539]
#     (3121, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013689398765563965]
#     (1616, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013984441757202148]
#     (7502, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001498579978942871]
#     (17782, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014390349388122559]
#     (2675, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011325478553771973]
#     (13193, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009174942970275879]
#     (6379, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014675259590148926]
#     (2583, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012229681015014648]
#     (11284, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013647675514221191]
#     (10082, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016368627548217773]
#     (11204, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012343525886535645]
#     (14218, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0017958283424377441]
#     (8267, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014899373054504395]
#     (812, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016692280769348145]
#     (8614, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013802647590637207]
#     (13172, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016270875930786133]
#     (10740, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001329958438873291]
#     (4710, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013048052787780762]
#     (14265, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013927817344665527]
#     (12908, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001313328742980957]
#     (711, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015385746955871582]
#     (2176, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013138651847839355]
#     (5654, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001356363296508789]
#     (4623, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001255035400390625]
#     (1721, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015644431114196777]
#     (4795, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011727213859558105]
#     (2742, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013055205345153809]
#     (2701, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014008283615112305]
#     (8036, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014666914939880371]
#     (15898, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014325976371765137]
#     (1255, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001537919044494629]
#     (4667, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011758208274841309]
#     (11058, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012055635452270508]
#     (10396, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014672279357910156]
#     (17152, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001361548900604248]
#     (6190, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015679001808166504]
#     (10025, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015144944190979004]
#     (354, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014742016792297363]
#     (886, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015227198600769043]
#     (4921, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014690160751342773]
#     (9386, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013118386268615723]
#     (7672, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001400768756866455]
#     (3198, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015560388565063477]
#     (17314, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015737414360046387]
#     (12930, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014972686767578125]
#     (7437, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013741850852966309]
#     (18416, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012583136558532715]
#     (741, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013066530227661133]
#     (4140, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016084909439086914]
#     (2863, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013427734375]
#     (15940, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013949275016784668]
#     (3281, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010551810264587402]
#     (10330, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001303255558013916]
#     (6324, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001233816146850586]
#     (420, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016358494758605957]
#     (4546, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012645125389099121]
#     (18771, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010442137718200684]
#     (11264, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014294981956481934]
#     (2854, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0016394257545471191]
#     (12141, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012522339820861816]
#     (12129, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013221502304077148]
#     (14553, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011578798294067383]
#     (473, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014031529426574707]
#     (5085, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011563897132873535]
#     (14471, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015990138053894043]
#     (3705, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010203719139099121]
#     (602, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013878941535949707]
#     (2021, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012981891632080078]
#     (9620, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001729130744934082]
#     (7638, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013409256935119629]
#     (9172, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010623335838317871]
#     (1849, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012158751487731934]
#     (15597, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011568665504455566]
#     (4745, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012112855911254883]
#     (6449, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012885332107543945]
#     (17516, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014833807945251465]
#     (2367, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011625289916992188]
#     (2629, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012720227241516113]
#     (10248, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001090407371520996]
#     (4307, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001282036304473877]
#     (4769, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001205146312713623]
#     (16886, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012745857238769531]
#     (743, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011429190635681152]
#     (2403, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013112425804138184]
#     (46, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001245737075805664]
#     (7078, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013357996940612793]
#     (4702, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012982487678527832]
#     (6420, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0015046000480651855]
#     (6742, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012761950492858887]
#     (750, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011385679244995117]
#     (2371, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001052558422088623]
#     (11417, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008782148361206055]
#     (1375, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011241436004638672]
#     (2526, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0018635988235473633]
#     (4611, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009599924087524414]
#     (3433, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011931061744689941]
#     (12285, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009897351264953613]
#     (15393, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011891722679138184]
#     (16838, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011371374130249023]
#     (3635, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014960169792175293]
#     (4893, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012407898902893066]
#     (12852, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012452006340026855]
#     (8587, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011118054389953613]
#     (3811, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000982046127319336]
#     (2461, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012251734733581543]
#     (1917, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001172780990600586]
#     (11036, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009987950325012207]
#     (19074, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011796951293945312]
#     (13935, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001016080379486084]
#     (8211, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011422038078308105]
#     (7557, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009895563125610352]
#     (7495, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001186370849609375]
#     (13182, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001447916030883789]
#     (12209, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011629462242126465]
#     (3877, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001109480857849121]
#     (12810, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014039874076843262]
#     (10796, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013399720191955566]
#     (12473, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013195276260375977]
#     (1230, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009175539016723633]
#     (4688, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001143038272857666]
#     (13323, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013470053672790527]
#     (6959, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009948015213012695]
#     (7621, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012386441230773926]
#     (8990, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011759400367736816]
#     (6796, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000823676586151123]
#     (15323, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011058449745178223]
#     (4983, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0014383196830749512]
#     (15146, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009298920631408691]
#     (11226, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007881522178649902]
#     (13264, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001021265983581543]
#     (5620, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009840726852416992]
#     (14435, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009029507637023926]
#     (5403, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011647343635559082]
#     (8229, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011559724807739258]
#     (2931, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011840462684631348]
#     (493, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009968876838684082]
#     (3458, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010467171669006348]
#     (10347, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013560652732849121]
#     (5117, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008303523063659668]
#     (13246, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010768771171569824]
#     (12083, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011433959007263184]
#     (14764, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009301304817199707]
#     (9927, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001033484935760498]
#     (10358, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011431574821472168]
#     (5721, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010616183280944824]
#     (2354, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001099228858947754]
#     (5210, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012006163597106934]
#     (5322, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00109940767288208]
#     (7969, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012235045433044434]
#     (8731, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010282397270202637]
#     (16323, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011311173439025879]
#     (3189, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004952549934387207]
#     (2127, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009434819221496582]
#     (1581, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009598135948181152]
#     (3509, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010129809379577637]
#     (2213, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011420845985412598]
#     (17796, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007681846618652344]
#     (19028, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009289383888244629]
#     (4300, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007407665252685547]
#     (5360, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012616515159606934]
#     (12673, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009328126907348633]
#     (16602, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010350942611694336]
#     (8863, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009950995445251465]
#     (553, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011187195777893066]
#     (9536, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008866786956787109]
#     (1176, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010616183280944824]
#     (20155, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010042786598205566]
#     (9511, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010524988174438477]
#     (6350, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0012081265449523926]
#     (367, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001098930835723877]
#     (9822, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009545683860778809]
#     (9911, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010468363761901855]
#     (17320, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.001063227653503418]
#     (7853, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008583664894104004]
#     (889, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013018250465393066]
#     (8353, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000883638858795166]
#     (375, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010983943939208984]
#     (4971, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008276700973510742]
#     (7002, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009461045265197754]
#     (11625, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009520053863525391]
#     (1372, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010718703269958496]
#     (3979, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009209513664245605]
#     (6181, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008349418640136719]
#     (8215, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009860992431640625]
#     (1631, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010422468185424805]
#     (13605, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011890530586242676]
#     (4924, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000865638256072998]
#     (8787, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009337663650512695]
#     (970, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008530020713806152]
#     (13319, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008077025413513184]
#     (5716, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009548068046569824]
#     (3936, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009420514106750488]
#     (1346, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008880496025085449]
#     (16321, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000681459903717041]
#     (5358, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000637352466583252]
#     (3182, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008920431137084961]
#     (13801, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007849931716918945]
#     (16685, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007666945457458496]
#     (6274, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008447766304016113]
#     (16044, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000895082950592041]
#     (9790, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007641315460205078]
#     (9768, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008154511451721191]
#     (6182, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011292099952697754]
#     (337, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006017684936523438]
#     (6890, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007982850074768066]
#     (4215, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0010349154472351074]
#     (202, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008876919746398926]
#     (6868, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0013135075569152832]
#     (2032, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008283853530883789]
#     (8806, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008218288421630859]
#     (17388, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007789731025695801]
#     (6601, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007362961769104004]
#     (4579, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007557272911071777]
#     (326, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007911324501037598]
#     (2662, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007858872413635254]
#     (2490, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006271004676818848]
#     (16173, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005423426628112793]
#     (731, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006905794143676758]
#     (10311, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006714463233947754]
#     (13518, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000674903392791748]
#     (745, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006607770919799805]
#     (4251, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005865693092346191]
#     (16400, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000836789608001709]
#     (10066, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007390975952148438]
#     (3707, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000638425350189209]
#     (4553, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006995201110839844]
#     (12379, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.004765450954437256]
#     (237, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007963776588439941]
#     (2360, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006794333457946777]
#     (11933, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008813142776489258]
#     (4237, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007073283195495605]
#     (1890, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000648796558380127]
#     (3378, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005794167518615723]
#     (12905, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004482865333557129]
#     (8783, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005602836608886719]
#     (5146, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000640571117401123]
#     (10039, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006133317947387695]
#     (9666, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005925893783569336]
#     (4223, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004469752311706543]
#     (13527, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008022189140319824]
#     (6168, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007684826850891113]
#     (7913, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005974769592285156]
#     (9413, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006644725799560547]
#     (9268, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004824995994567871]
#     (1513, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000569760799407959]
#     (16959, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006906390190124512]
#     (17240, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006488561630249023]
#     (1284, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007545351982116699]
#     (7412, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00048655271530151367]
#     (1303, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006404519081115723]
#     (3406, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005472302436828613]
#     (8569, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0003198981285095215]
#     (4732, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000437319278717041]
#     (8662, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000395357608795166]
#     (1373, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004748702049255371]
#     (5850, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00031000375747680664]
#     (6538, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004941225051879883]
#     (9357, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000729978084564209]
#     (4038, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005792379379272461]
#     (15510, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006739497184753418]
#     (4407, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004099607467651367]
#     (8777, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007169842720031738]
#     (16545, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007897019386291504]
#     (737, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006682276725769043]
#     (13216, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005232095718383789]
#     (6740, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005903840065002441]
#     (4079, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006489157676696777]
#     (11104, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000584721565246582]
#     (1900, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006310343742370605]
#     (5288, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006650090217590332]
#     (7090, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000455319881439209]
#     (14347, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007776618003845215]
#     (10602, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005079507827758789]
#     (18471, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00048416852951049805]
#     (7187, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006662607192993164]
#     (9306, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005495548248291016]
#     (7656, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006999969482421875]
#     (8701, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004934072494506836]
#     (8664, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00045686960220336914]
#     (8419, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005034804344177246]
#     (706, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005703568458557129]
#     (8290, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000648200511932373]
#     (4454, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006064772605895996]
#     (9599, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006915926933288574]
#     (6376, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0009005069732666016]
#     (16016, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00048404932022094727]
#     (379, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006537437438964844]
#     (12860, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00043767690658569336]
#     (17077, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0007302165031433105]
#     (958, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006424188613891602]
#     (723, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006492137908935547]
#     (8899, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004481077194213867]
#     (8434, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005456209182739258]
#     (13106, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000630795955657959]
#     (4729, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006211400032043457]
#     (9416, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005210041999816895]
#     (9560, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005984902381896973]
#     (4765, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006660819053649902]
#     (14011, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004608035087585449]
#     (5168, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005251169204711914]
#     (14709, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00043529272079467773]
#     (1140, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006676316261291504]
#     (1368, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006196498870849609]
#     (4014, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000490725040435791]
#     (14771, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0005784034729003906]
#     (103, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0004704594612121582]
#     (9596, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0008187294006347656]
#     (7368, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0006349086761474609]
#     (2169, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0002904534339904785]
# ...
#       Length: 1
#       First 5 values: [0.00044906139373779297]
#     (16545, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00032711029052734375]
#     (737, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004744529724121094]
#     (13216, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004308968782424927]
#     (6740, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003197789192199707]
#     (4079, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004002004861831665]
#     (11104, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00018671154975891113]
#     (1900, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004641413688659668]
#     (5288, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00039055943489074707]
#     (7090, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00021225214004516602]
#     (14347, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004176199436187744]
#     (10602, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0005039870738983154]
#     (18471, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00018680095672607422]
#     (7187, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00021892786026000977]
#     (9306, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003237426280975342]
#     (7656, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0005189478397369385]
#     (8701, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003552436828613281]
#     (8664, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002384781837463379]
#     (8419, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002171248197555542]
#     (706, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002357959747314453]
#     (8290, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0005075931549072266]
#     (4454, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004024803638458252]
#     (9599, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00047992169857025146]
#     (6376, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0005737841129302979]
#     (16016, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00024199485778808594]
#     (379, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00047516822814941406]
#     (12860, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0001033395528793335]
#     (17077, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.000533759593963623]
#     (958, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00045236945152282715]
#     (723, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00037148594856262207]
#     (8899, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004262775182723999]
#     (8434, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004697740077972412]
#     (13106, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00042751431465148926]
#     (4729, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002590566873550415]
#     (9416, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004748106002807617]
#     (9560, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00016638636589050293]
#     (4765, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00041066110134124756]
#     (14011, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [3.224611282348633e-05]
#     (5168, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004159212112426758]
#     (14709, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [9.575486183166504e-05]
#     (1140, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.000443190336227417]
#     (1368, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004545152187347412]
#     (4014, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00019724667072296143]
#     (14771, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004162788391113281]
#     (103, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00024168193340301514]
#     (9596, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00046947598457336426]
#     (7368, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0006287842988967896]
#     (2169, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00019018352031707764]
#     (9391, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003871023654937744]
#     (9410, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003726482391357422]
#     (3568, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [7.59512186050415e-05]
#     (2893, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00041484832763671875]
#     (4402, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00023663043975830078]
#     (12940, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002532452344894409]
#     (16280, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002116858959197998]
#     (12614, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00044608116149902344]
#     (7768, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0005336403846740723]
#     (12104, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002700686454772949]
#     (7222, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.000565841794013977]
#     (10080, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00014166533946990967]
#     (1485, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003648996353149414]
#     (8178, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002572089433670044]
#     (16304, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00012899935245513916]
#     (16157, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0007212311029434204]
#     (4959, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-7.137656211853027e-05]
#     (4461, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003262162208557129]
#     (551, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00016430020332336426]
#     (3664, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003583580255508423]
#     (9247, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00011369585990905762]
#     (17473, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00012284517288208008]
#     (4377, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [5.678832530975342e-05]
#     (1147, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [9.942054748535156e-05]
#     (2826, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00014466047286987305]
#     (12877, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00017750263214111328]
#     (8885, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0001828223466873169]
#     (1892, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-4.7147274017333984e-05]
#     (9369, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002872049808502197]
#     (2190, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00018155574798583984]
#     (5962, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00015082955360412598]
#     (12358, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00012825429439544678]
#     (9227, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00029915571212768555]
#     (8623, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00012356042861938477]
#     (14979, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00026658177375793457]
#     (7819, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003663599491119385]
#     (8444, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00035509467124938965]
#     (3896, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00013555586338043213]
#     (728, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002509951591491699]
#     (10190, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00029212236404418945]
#     (9245, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0001017153263092041]
#     (12470, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00016051530838012695]
#     (14533, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003489255905151367]
#     (2246, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002556741237640381]
#     (12449, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002545267343521118]
#     (12192, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002695918083190918]
#     (15390, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004285275936126709]
#     (9561, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00038267672061920166]
#     (17367, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003037750720977783]
#     (6817, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003561675548553467]
#     (13846, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-1.290440559387207e-05]
#     (4141, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00022812187671661377]
#     (5869, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [7.826089859008789e-05]
#     (5259, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [8.662045001983643e-05]
#     (15316, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0001688748598098755]
#     (665, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00014290213584899902]
#     (15008, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00016123056411743164]
#     (10052, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00020712614059448242]
#     (12688, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0001461803913116455]
#     (15680, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.000352710485458374]
#     (11097, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00032426416873931885]
#     (5515, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00041180849075317383]
#     (8520, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002646148204803467]
#     (9337, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00013870000839233398]
#     (3763, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [2.6404857635498047e-05]
#     (14168, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0001537799835205078]
#     (9649, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0001341402530670166]
#     (3535, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003413856029510498]
#     (9064, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002913177013397217]
#     (11910, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004766881465911865]
#     (15517, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00014579296112060547]
#     (10267, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002479851245880127]
#     (648, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00012788176536560059]
#     (10866, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-1.634657382965088e-05]
#     (4621, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [6.039440631866455e-05]
#     (552, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003937631845474243]
#     (8643, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002468526363372803]
#     (15339, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [4.887580871582031e-06]
#     (5229, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00021858513355255127]
#     (15182, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0002012699842453003]
#     (6391, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [3.203749656677246e-06]
#     (4148, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00014136731624603271]
#     (8855, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [5.564093589782715e-05]
#     (9251, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00020720064640045166]
#     (13137, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [7.475912570953369e-05]
#     (6613, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00018483400344848633]
#     (7685, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00012354552745819092]
#     (12920, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [9.679794311523438e-05]
#     (15041, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-7.556378841400146e-05]
#     (1399, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00017654895782470703]
#     (8573, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-2.7000904083251953e-05]
#     (14701, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00014480948448181152]
#     (955, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-7.447600364685059e-05]
#     (9170, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [7.605552673339844e-05]
#     (14077, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0005297809839248657]
#     (13733, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004170536994934082]
#     (11255, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-9.945034980773926e-05]
#     (1017, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00012446939945220947]
#     (410, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-7.857382297515869e-05]
#     (12618, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003394186496734619]
#     (15304, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [4.9948692321777344e-05]
#     (15027, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.000246584415435791]
#     (14280, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00013653934001922607]
#     (6941, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.00020200014114379883]
#     (9532, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.00018727779388427734]
#     (8857, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0003479272127151489]
#     (16561, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0004474073648452759]
#     (8380, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [0.0009461939334869385]
#     (3, 'cell_emb'): <class 'list'>
#       Length: 1
#       First 5 values: [-0.0011855363845825195]
#
# 🎯 Results loaded into 'perturbation_results' variable!
